# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\nickr\OneDrive\Documents\Nick Bootcamp\Python\Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_ord_pro_com = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ord_pro_com = df_ord_pro_com.drop(columns = ['_merge'])

# %%
df_ord_pro_com = df_ord_pro_com.drop(columns = ['Unnamed: 0'])

# %%
df_ord_pro_com = df_ord_pro_com.drop(columns = ['Unnamed: 0.1'])

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49688       49688       49684
# 49689       49689       49685
# 49690       49690       49686
# 49691       49691       49687
# 49692       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49688          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods.info
# Out:
# <bound method DataFrame.info of        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# ...

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
df_prods['department_id'] = df_prods['department_id'].astype('int8')

# %%
df_prods['aisle_id'] = df_prods['aisle_id'].astype('int16')

# %%
df_ord_pro_com.info
# Out:
# <bound method DataFrame.info of           order_id  user_id  order_number  orders_days_of_week  \
# 0          2539329        1             1                    2
# 1          2539329        1             1                    2
# 2          2539329        1             1                    2
# 3          2539329        1             1                    2
# 4          2539329        1             1                    2
# ...            ...      ...           ...                  ...
# 32434484   2977660   206209            13                    1
# 32434485   2977660   206209            13                    1
# 32434486   2977660   206209            13                    1
# 32434487   2977660   206209            13                    1
# 32434488   2977660   206209            13                    1
#
#           hour_of_day_ordered  days_since_prior_order  product_id  \
# 0                           8                     NaN         196
# ...

# %%
df_ord_pro_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_days_of_week     int64
#  4   hour_of_day_ordered     int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
# dtypes: float64(1), int64(8)
# memory usage: 2.2 GB

# %%
df_ord_pro_com.head()
# Out:
#    order_id  user_id  order_number  orders_days_of_week  hour_of_day_ordered  \
# 0   2539329        1             1                    2                    8
# 1   2539329        1             1                    2                    8
# 2   2539329        1             1                    2                    8
# 3   2539329        1             1                    2                    8
# 4   2539329        1             1                    2                    8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
df_ord_pro_com['orders_days_of_week'] = df_ord_pro_com['orders_days_of_week'].astype('int8')

# %%
df_ord_pro_com['hour_of_day_ordered'] = df_ord_pro_com['hour_of_day_ordered'].astype('int8')

# %%
df_ord_pro_com['reordered'] = df_ord_pro_com['reordered'].astype('int16')

# %%
df_ord_pro_com['product_id'] = df_ord_pro_com['product_id'].astype('int32')

# %%
df_prods['product_id'] = df_prods['product_id'].astype('int32')

# %%
df_ords_prods_merged = df_prods.merge(df_ord_pro_com, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_days_of_week  hour_of_day_ordered  \
# 0   3139998      138            28                    6                   11
# 1   1977647      138            30                    6                   17
# 2    389851      709             2                    0                   21
# 3    652770      764             1                    3                   13
# 4   1813452      764             3                    4                   17
#
# ...

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))
